# %%
import os
from PIL import Image
import pytesseract
import cv2
import matplotlib as mpl
mpl.use('TkAgg')
from matplotlib import pyplot as plt
print("OpenCV Version :{} ".format(cv2.__version__))
# Out:
# OpenCV Version :4.0.0

# %%
# %matplotlib inline

# %% [markdown]
# # Test sur une seule image

# %%
Image.open('../01_alb_id.tif')
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=1040x653 at 0x10EFA9908>

# %%
output = pytesseract.image_to_string(Image.open('../01_alb_id.tif'))
print(output)
# Out:
# » LY LIKA.E SHO SS \
# | REEUBLICA E SHOIPERISE,
#
# Wl bo ene
# aa i : ):
# O- = .
#
#
#
#
#
#
#
#
#
#
#
# personal/personal no.
#
# 1051019999 |

# %%
file = open("../text_outputs/outputPython.txt","w") 
file.write(output) 
file.close()

# %% [markdown]
# # Test sur une image préprocessée par défaut par Tesseract C++

# %%
path_prepro = "../preprocessed_images/"

# %%
Image.open(path_prepro + 'preprocess_tesseract.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=1040x653 at 0x11CF7D668>

# %%
output = pytesseract.image_to_string(Image.open(path_prepro + 'preprocess_tesseract.png'))
print(output)
# Out:
# ea)
#
# aN W’
#
# salty: :
#
# Re MM YY GG
#
#
#
# aft
